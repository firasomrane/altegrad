# %%
import string
from nltk.corpus import stopwords
from igraph import *

#import os
#os.chdir() # to change working directory to where functions live
# import custom functions
from library import clean_text_simple, terms_to_graph, core_dec

# %%
stpwds = stopwords.words('english')
punct = string.punctuation.replace('-', '')

my_doc = 'A method for solution of systems of linear algebraic equations \
with m-dimensional lambda matrices. A system of linear algebraic \
equations with m-dimensional lambda matrices is considered. \
The proposed method of searching for the solution of this from library import clean_text_simple, system \
lies in reducing it to a numerical system of a special kind.'

# my_doc = 'graph text mining density graph text mining'

my_doc = my_doc.replace('\n', '')

# pre-process document
my_tokens = clean_text_simple(my_doc,my_stopwords=stpwds,punct=punct)
g = terms_to_graph(my_tokens, 4)

# number of edges
print(len(g.es))

# the number of nodes should be equal to the number of unique terms
len(g.vs) == len(set(my_tokens))
print(g.vs[0])

edge_weights = []
for edge in g.es:
    source = g.vs[edge.source]['name']
    target = g.vs[edge.target]['name']
    weight = edge['weight']
    edge_weights.append([source, target, weight])

print(edge_weights)
layout = g.layout("kk")
plot(g, layout = layout)

for w in range(2,10):
    g = terms_to_graph(my_tokens, w)
    ### fill the gap (print density of g) ###
    print('The density with a window of size {} is: {}'.format( w, g.density()))
    
    
# decompose g
core_numbers = core_dec(g,False)
print(core_numbers)

### fill the gap (compare 'core_numbers' with the output of the .coreness() igraph method) ###

# retain main core as keywords
max_c_n = max(core_numbers.values())
keywords = [kwd for kwd, c_n in core_numbers.items() if c_n == max_c_n]
print(keywords)
# Out:
# 53
# igraph.Vertex(<igraph.Graph object at 0x7f1021f586d8>, 0, {'name': 'algebra', 'weight': 12.0})
# [['method', 'solut', 2], ['method', 'system', 1], ['method', 'linear', 1], ['solut', 'system', 1], ['solut', 'linear', 1], ['system', 'linear', 2], ['solut', 'algebra', 1], ['system', 'algebra', 2], ['linear', 'algebra', 2], ['system', 'equat', 2], ['linear', 'equat', 2], ['algebra', 'equat', 2], ['linear', 'm-dimension', 2], ['algebra', 'm-dimension', 2], ['equat', 'm-dimension', 2], ['algebra', 'lambda', 2], ['equat', 'lambda', 2], ['m-dimension', 'lambda', 2], ['equat', 'system', 1], ['m-dimension', 'system', 1], ['lambda', 'system', 1], ['m-dimension', 'linear', 1], ['lambda', 'linear', 1], ['lambda', 'algebra', 1], ['equat', 'matric', 1], ['m-dimension', 'matric', 1], ['lambda', 'matric', 1], ['m-dimension', 'method', 1], ['lambda', 'method', 1], ['matric', 'method', 1], ['lambda', 'solut', 1], ['matric', 'solut', 1], ['matric', 'librari', 1], ['method', 'librari', 1], ['solut', 'librari', 1], ['method', 'import', 1], ['solut', 'import', 1], ['librari', 'import', 1], ['solut', 'cleantextsimpl', 1], ['librari', 'cleantextsimpl', 1], ['import', 'cleantextsimpl', 1], ['librari', 'system', 1], ['import', 'system', 1], ['cleantextsimpl', 'system', 2], ['import', 'numer', 1], ['cleantextsimpl', 'numer', 1], ['system', 'numer', 1], ['numer', 'system', 1], ['system', 'special', 2], ['numer', 'special', 1], ['numer', 'kind', 1], ['system', 'kind', 1], ['special', 'kind', 1]]
# The density with a window of size 2 is: 0.08571428571428572
# The density with a window of size 3 is: 0.17142857142857143
# The density with a window of size 4 is: 0.2523809523809524
# The density with a window of size 5 is: 0.32857142857142857
# The density with a window of size 6 is: 0.4095238095238095
# The density with a window of size 7 is: 0.4666666666666667
# The density with a window of size 8 is: 0.5095238095238096
# The density with a window of size 9 is: 0.5476190476190477
# min degree:  7.0
# top:  kind  index  4
# neighbors :  ['cleantextsimpl', 'import', 'librari', 'numer', 'solut', 'special', 'system']
# <igraph.EdgeSeq object at 0x7f101fddf728>
# after deletion:  ['algebra', 'cleantextsimpl', 'equat', 'import', 'lambda', 'librari', 'linear', 'm-dimension', 'matric', 'method', 'numer', 'solut', 'special', 'system']
# min degree:  8.0
# top:  special  index  12
# neighbors :  ['cleantextsimpl', 'import', 'librari', 'method', 'numer', 'solut', 'system']
# <igraph.EdgeSeq object at 0x7f101fddfb48>
# after deletion:  ['algebra', 'cleantextsimpl', 'equat', 'import', 'lambda', 'librari', 'linear', 'm-dimension', 'matric', 'method', 'numer', 'solut', 'system']
# min degree:  11.0
# top:  numer  index  10
# neighbors :  ['cleantextsimpl', 'import', 'lambda', 'librari', 'matric', 'method', 'solut', 'system']
# <igraph.EdgeSeq object at 0x7f101fddf6d0>
# after deletion:  ['algebra', 'cleantextsimpl', 'equat', 'import', 'lambda', 'librari', 'linear', 'm-dimension', 'matric', 'method', 'solut', 'system']
# min degree:  12.0
# top:  cleantextsimpl  index  1
# neighbors :  ['equat', 'import', 'lambda', 'librari', 'm-dimension', 'matric', 'method', 'solut']
# <igraph.EdgeSeq object at 0x7f101fddfbf8>
# after deletion:  ['algebra', 'equat', 'import', 'lambda', 'librari', 'linear', 'm-dimension', 'matric', 'method', 'solut', 'system']
# min degree:  13.0
# top:  import  index  2
# neighbors :  ['algebra', 'equat', 'lambda', 'librari', 'm-dimension', 'matric', 'method', 'solut']
# <igraph.EdgeSeq object at 0x7f101fddf6d0>
# after deletion:  ['algebra', 'equat', 'lambda', 'librari', 'linear', 'm-dimension', 'matric', 'method', 'solut', 'system']
# min degree:  13.0
# top:  matric  index  6
# neighbors :  ['algebra', 'equat', 'lambda', 'librari', 'linear', 'm-dimension', 'method', 'system']
# <igraph.EdgeSeq object at 0x7f101fddfb48>
# after deletion:  ['algebra', 'equat', 'lambda', 'librari', 'linear', 'm-dimension', 'method', 'solut', 'system']
# min degree:  14.0
# top:  librari  index  3
# neighbors :  ['algebra', 'equat', 'lambda', 'linear', 'm-dimension', 'method', 'solut']
# <igraph.EdgeSeq object at 0x7f101fddf728>
# after deletion:  ['algebra', 'equat', 'lambda', 'linear', 'm-dimension', 'method', 'solut', 'system']
# min degree:  16.0
# top:  linear  index  3
# neighbors :  ['algebra', 'm-dimension']
# <igraph.EdgeSeq object at 0x7f101fddfbf8>
# after deletion:  ['algebra', 'equat', 'lambda', 'm-dimension', 'method', 'solut', 'system']
# min degree:  17.0
# top:  algebra  index  0
# neighbors :  ['equat', 'lambda', 'm-dimension', 'method', 'solut', 'system']
# <igraph.EdgeSeq object at 0x7f101fddf6d0>
# after deletion:  ['equat', 'lambda', 'm-dimension', 'method', 'solut', 'system']
# min degree:  18.0
# top:  equat  index  0
# neighbors :  []
# <igraph.EdgeSeq object at 0x7f101fddf728>
# after deletion:  ['lambda', 'm-dimension', 'method', 'solut', 'system']
# min degree:  18.0
# top:  m-dimension  index  1
# neighbors :  []
# <igraph.EdgeSeq object at 0x7f101fddfb48>
# after deletion:  ['lambda', 'method', 'solut', 'system']
# min degree:  19.0
# top:  lambda  index  0
# neighbors :  []
# <igraph.EdgeSeq object at 0x7f101fddfbf8>
# after deletion:  ['method', 'solut', 'system']
# min degree:  19.0
# top:  method  index  0
# neighbors :  []
# <igraph.EdgeSeq object at 0x7f101fddfa98>
# after deletion:  ['solut', 'system']
# min degree:  20.0
# top:  solut  index  0
# neighbors :  []
# <igraph.EdgeSeq object at 0x7f101fddf6d0>
# after deletion:  ['system']
# min degree:  25.0
# top:  system  index  0
# neighbors :  []
# <igraph.EdgeSeq object at 0x7f101fddf728>
# after deletion:  []
# {'algebra': 17.0, 'cleantextsimpl': 12.0, 'equat': 18.0, 'import': 13.0, 'kind': 7.0, 'lambda': 19.0, 'librari': 14.0, 'linear': 16.0, 'm-dimension': 18.0, 'matric': 13.0, 'method': 19.0, 'numer': 11.0, 'solut': 20.0, 'special': 8.0, 'system': 25.0}
# ['system']

# %%
# decompose g
core_numbers = core_dec(g,False)
print(core_numbers)

### fill the gap (compare 'core_numbers' with the output of the .coreness() igraph method) ###

# retain main core as keywords
max_c_n = max(core_numbers.values())
keywords = [kwd for kwd, c_n in core_numbers.items() if c_n == max_c_n]
print(keywords)
